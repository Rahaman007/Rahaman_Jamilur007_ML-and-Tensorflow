# %% [markdown]
# <a href="https://colab.research.google.com/github/Rahaman007/Rahaman_Jamilur007_ML-and-Tensorflow/blob/main/Image_Classification_with_CNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2
import os
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import VGG16
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam

# Set paths for training and testing datasets
train_dir = 'path_to_training_dataset'
test_dir = 'path_to_test_dataset'

# Function to display sample images from the dataset
def plot_sample_images(image_dir, num_samples=10):
    categories = os.listdir(image_dir)
    fig, axes = plt.subplots(1, num_samples, figsize=(20, 20))
    for idx, category in enumerate(categories[:num_samples]):
        img_path = os.path.join(image_dir, category, os.listdir(os.path.join(image_dir, category))[0])
        image = cv2.imread(img_path)
        axes[idx].imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
        axes[idx].set_title(category)
        axes[idx].axis('off')
    plt.show()

# Display sample images
plot_sample_images(train_dir)

# Data augmentation and preprocessing
train_datagen = ImageDataGenerator(rescale=1./255, rotation_range=20, zoom_range=0.2, horizontal_flip=True)
test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(train_dir, target_size=(224, 224), batch_size=32, class_mode='categorical')
test_generator = test_datagen.flow_from_directory(test_dir, target_size=(224, 224), batch_size=32, class_mode='categorical')

# Load pre-trained VGG16 model + higher level layers
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Freeze convolutional layers
for layer in base_model.layers:
    layer.trainable = False

# Build and compile the model
model = Sequential([
    base_model,
    Flatten(),
    Dense(256, activation='relu'),
    Dropout(0.5),
    Dense(train_generator.num_classes, activation='softmax')
])

model.compile(optimizer=Adam(lr=0.001), loss='categorical_crossentropy', metrics=['accuracy'])

# Early stopping to prevent overfitting
early_stopping = EarlyStopping(monitor='val_accuracy', patience=5, restore_best_weights=True)

# Train the model
history = model.fit(train_generator, validation_data=test_generator, epochs=20, callbacks=[early_stopping])

# Visualize training history
def plot_history(history):
    plt.plot(history.history['accuracy'], label='Training Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.show()

plot_history(history)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-2c00f861b33e> in <cell line: 32>()
#      30
#      31 # Display sample images
# ---> 32 plot_sample_images(train_dir)
#      33
#      34 # Data augmentation and preprocessing
#
# <ipython-input-1-2c00f861b33e> in plot_sample_images(image_dir, num_samples)
#      19 # Function to display sample images from the dataset
#      20 def plot_sample_images(image_dir, num_samples=10):
# ---> 21     categories = os.listdir(image_dir)
#      22     fig, axes = plt.subplots(1, num_samples, figsize=(20, 20))
#      23     for idx, category in enumerate(categories[:num_samples]):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'path_to_training_dataset'

# %%
# Import necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2
import os
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import VGG16
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam

# Set paths for training and testing datasets
# Make sure these paths are correct and the directories exist
train_dir = 'dataset/train' # Update with the actual path to your training dataset
test_dir = 'dataset/test'     # Update with the actual path to your test dataset

# Function to display sample images from the dataset
def plot_sample_images(image_dir, num_samples=10):
    categories = os.listdir(image_dir)
    fig, axes = plt.subplots(1, num_samples, figsize=(20, 20))
    for idx, category in enumerate(categories[:num_samples]):
        category_path = os.path.join(image_dir, category)
        if os.path.isdir(category_path):  # Check if it's a directory
            files = os.listdir(category_path)
            if files:
                img_path = os.path.join(category_path, files[0])
                image = cv2.imread(img_path)
                if image is not None:
                    axes[idx].imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
                    axes[idx].set_title(category)
                    axes[idx].axis('off')
    plt.show()

# Display sample images
plot_sample_images(train_dir)

# Data augmentation and preprocessing
train_datagen = ImageDataGenerator(rescale=1./255, rotation_range=20, zoom_range=0.2, horizontal_flip=True)
test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(train_dir, target_size=(224, 224), batch_size=32, class_mode='categorical')
test_generator = test_datagen.flow_from_directory(test_dir, target_size=(224, 224), batch_size=32, class_mode='categorical')

# Load pre-trained VGG16 model + higher level layers
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Freeze convolutional layers
for layer in base_model.layers:
    layer.trainable = False

# Build and compile the model
model = Sequential([
    base_model,
    Flatten(),
    Dense(256, activation='relu'),
    Dropout(0.5),
    Dense(train_generator.num_classes, activation='softmax')
])

model.compile(optimizer=Adam(lr=0.001), loss='categorical_crossentropy', metrics=['accuracy'])

# Early stopping to prevent overfitting
early_stopping = EarlyStopping(monitor='val_accuracy', patience=5, restore_best_weights=True)

# Train the model
history = model.fit(train_generator, validation_data=test_generator, epochs=20, callbacks=[early_stopping])

# Visualize training history
def plot_history(history):
    plt.plot(history.history['accuracy'], label='Training Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.show()

plot_history(history)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-6600973fb465> in <cell line: 38>()
#      36
#      37 # Display sample images
# ---> 38 plot_sample_images(train_dir)
#      39
#      40 # Data augmentation and preprocessing
#
# <ipython-input-2-6600973fb465> in plot_sample_images(image_dir, num_samples)
#      20 # Function to display sample images from the dataset
#      21 def plot_sample_images(image_dir, num_samples=10):
# ---> 22     categories = os.listdir(image_dir)
#      23     fig, axes = plt.subplots(1, num_samples, figsize=(20, 20))
#      24     for idx, category in enumerate(categories[:num_samples]):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'dataset/train'

# %%
# Import necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2
import os
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import VGG16
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam

# Set paths for training and testing datasets
# Make sure these paths are correct and the directories exist
train_dir = 'dataset/train' # Update with the actual path to your training dataset
test_dir = 'dataset/test'     # Update with the actual path to your test dataset

# Function to display sample images from the dataset
def plot_sample_images(image_dir, num_samples=10):
    categories = os.listdir(image_dir)
    fig, axes = plt.subplots(1, num_samples, figsize=(20, 20))
    for idx, category in enumerate(categories[:num_samples]):
        category_path = os.path.join(image_dir, category)
        if os.path.isdir(category_path):  # Check if it's a directory
            files = os.listdir(category_path)
            if files:
                img_path = os.path.join(category_path, files[0])
                image = cv2.imread(img_path)
                if image is not None:
                    axes[idx].imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
                    axes[idx].set_title(category)
                    axes[idx].axis('off')
    plt.show()

# Display sample images
plot_sample_images(train_dir)

# Data augmentation and preprocessing
train_datagen = ImageDataGenerator(rescale=1./255, rotation_range=20, zoom_range=0.2, horizontal_flip=True)
test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(train_dir, target_size=(224, 224), batch_size=32, class_mode='categorical')
test_generator = test_datagen.flow_from_directory(test_dir, target_size=(224, 224), batch_size=32, class_mode='categorical')

# Load pre-trained VGG16 model + higher level layers
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Freeze convolutional layers
for layer in base_model.layers:
    layer.trainable = False

# Build and compile the model
model = Sequential([
    base_model,
    Flatten(),
    Dense(256, activation='relu'),
    Dropout(0.5),
    Dense(train_generator.num_classes, activation='softmax')
])

model.compile(optimizer=Adam(lr=0.001), loss='categorical_crossentropy', metrics=['accuracy'])

# Early stopping to prevent overfitting
early_stopping = EarlyStopping(monitor='val_accuracy', patience=5, restore_best_weights=True)

# Train the model
history = model.fit(train_generator, validation_data=test_generator, epochs=20, callbacks=[early_stopping])

# Visualize training history
def plot_history(history):
    plt.plot(history.history['accuracy'], label='Training Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.show()

plot_history(history)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-6600973fb465> in <cell line: 38>()
#      36
#      37 # Display sample images
# ---> 38 plot_sample_images(train_dir)
#      39
#      40 # Data augmentation and preprocessing
#
# <ipython-input-3-6600973fb465> in plot_sample_images(image_dir, num_samples)
#      20 # Function to display sample images from the dataset
#      21 def plot_sample_images(image_dir, num_samples=10):
# ---> 22     categories = os.listdir(image_dir)
#      23     fig, axes = plt.subplots(1, num_samples, figsize=(20, 20))
#      24     for idx, category in enumerate(categories[:num_samples]):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'dataset/train'
